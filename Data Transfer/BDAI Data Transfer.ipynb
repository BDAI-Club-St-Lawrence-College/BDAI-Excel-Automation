# %%
import pandas as pd

dfatt = pd.read_csv (r"C:\Users\Hennadii\Desktop\Attendance.csv")

# %%
dfcont = pd.read_csv (r"C:\Users\Hennadii\Desktop\Contract.csv")

# %%
display(dfatt,dfcont)
# Out:
#              ID  Name ContractType       Date StartTime EndTime  Unnamed: 6
# 0     3978144.0   Ann            B  1/25/2017     13:09   16:08         NaN
# 1     3588609.0   Sam            C  1/27/2017     13:20   23:27         NaN
# 2     3015452.0   Sam            A  1/28/2017     14:55   20:42         NaN
# 3     7697278.0  Matt            C   2/4/2017     14:37   20:56         NaN
# 4     6223708.0  Lucy            C   2/4/2017     14:59   23:10         NaN
# ...         ...   ...          ...        ...       ...     ...         ...
# 9616        NaN   NaN          NaN        NaN       NaN     NaN         NaN
# 9617        NaN   NaN          NaN        NaN       NaN     NaN         NaN
# 9618        NaN   NaN          NaN        NaN       NaN     NaN         NaN
# 9619        NaN   NaN          NaN        NaN       NaN     NaN         NaN
# 9620        NaN   NaN          NaN        NaN       NaN     NaN         NaN
#
# [9621 rows x 7 columns]
# ...

# %%
dfcont = dfcont[0:30] #deleted empty rows

# %%
dfatt = dfatt[0:7241] #deleted empty rows

# %%
display(dfatt,dfcont)
# Out:
#              ID      Name ContractType       Date StartTime EndTime  \
# 0     3978144.0       Ann            B  1/25/2017     13:09   16:08
# 1     3588609.0       Sam            C  1/27/2017     13:20   23:27
# 2     3015452.0       Sam            A  1/28/2017     14:55   20:42
# 3     7697278.0      Matt            C   2/4/2017     14:37   20:56
# 4     6223708.0      Lucy            C   2/4/2017     14:59   23:10
# ...         ...       ...          ...        ...       ...     ...
# 7236  2274833.0      Dora            B   6/1/2022     14:31   19:45
# 7237  5596179.0       Sam            C   6/1/2022     11:15   18:20
# 7238  6774606.0      Tony            C   6/1/2022     11:05   23:36
# 7239  1571029.0    George            A   6/1/2022     12:47   22:24
# 7240  3038583.0  Jennifer            A   6/1/2022     13:01   18:57
#
#       Unnamed: 6
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 7236         NaN
# ...

# %%
dfcont['merge_id'] = dfcont['Name'] + ', ' + dfcont['Type']
dfcont.head(15)

#created a unique id to merge tables
# Out:
# C:\Users\Hennadii\AppData\Local\Temp/ipykernel_12484/3334380329.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfcont['merge_id'] = dfcont['Name'] + ', ' + dfcont['Type']
#         Name Type   StartDate     EndDate HourlyPay     merge_id
# 0        Vic    A   4/12/2018   6/29/2029    $22.61       Vic, A
# 1        Ann    A  10/28/2012   8/15/2030    $32.68       Ann, A
# 2       Adam    A   8/19/2020   9/16/2026    $33.22      Adam, A
# 3       Tony    A  11/26/2015   1/19/2026    $26.71      Tony, A
# 4       Dora    A   4/15/2020   5/30/2030    $30.29      Dora, A
# 5   Jennifer    A   3/11/2010   4/21/2023    $30.42  Jennifer, A
# 6        Sam    A   5/18/2015   7/29/2028    $29.93       Sam, A
# ...

# %%
dfatt['merge_id'] = dfatt['Name'] + ', ' + dfatt['ContractType']
dfatt.head(15)

#created a unique id to merge tables
# Out:
#            ID      Name ContractType       Date StartTime EndTime  Unnamed: 6  \
# 0   3978144.0       Ann            B  1/25/2017     13:09   16:08         NaN
# 1   3588609.0       Sam            C  1/27/2017     13:20   23:27         NaN
# 2   3015452.0       Sam            A  1/28/2017     14:55   20:42         NaN
# 3   7697278.0      Matt            C   2/4/2017     14:37   20:56         NaN
# 4   6223708.0      Lucy            C   2/4/2017     14:59   23:10         NaN
# 5   7307931.0       Sam            A   2/9/2017     14:23   20:40         NaN
# 6   3223969.0    George            A   2/9/2017     13:51   23:14         NaN
# 7   9933171.0    George            C  2/21/2017     13:05   21:11         NaN
# 8   4389168.0      Dora            A  2/22/2017     11:15   19:53         NaN
# 9   1884775.0      Matt            C  2/22/2017     12:56   19:31         NaN
# 10  1989304.0  Jennifer            C  2/22/2017     11:14   16:26         NaN
# ...

# %%
dfall = pd.merge(dfcont,dfatt, on='merge_id')
dfall = dfall.iloc[:,:-1]
dfall

#deleted last empty column
# Out:
#      Name_x Type  StartDate     EndDate HourlyPay merge_id         ID Name_y  \
# 0       Vic    A  4/12/2018   6/29/2029    $22.61   Vic, A  1825144.0    Vic
# 1       Vic    A  4/12/2018   6/29/2029    $22.61   Vic, A  2533835.0    Vic
# 2       Vic    A  4/12/2018   6/29/2029    $22.61   Vic, A  1132295.0    Vic
# 3       Vic    A  4/12/2018   6/29/2029    $22.61   Vic, A  8910879.0    Vic
# 4       Vic    A  4/12/2018   6/29/2029    $22.61   Vic, A  8643060.0    Vic
# ...     ...  ...        ...         ...       ...      ...        ...    ...
# 7236   Lucy    C   7/9/2017  12/27/2028    $23.62  Lucy, C  9733692.0   Lucy
# 7237   Lucy    C   7/9/2017  12/27/2028    $23.62  Lucy, C  6257803.0   Lucy
# 7238   Lucy    C   7/9/2017  12/27/2028    $23.62  Lucy, C  4098481.0   Lucy
# 7239   Lucy    C   7/9/2017  12/27/2028    $23.62  Lucy, C  2322516.0   Lucy
# 7240   Lucy    C   7/9/2017  12/27/2028    $23.62  Lucy, C  2885021.0   Lucy
#
# ...

# %%
dfall['StartDate'] = pd.to_datetime(dfall['StartDate'])
dfall['EndDate'] = pd.to_datetime(dfall['EndDate'])
dfall['Date'] = pd.to_datetime(dfall['Date'])
dfall.info()

#converted numeric dates into date format using pandas ( datetime64[ns])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7241 entries, 0 to 7240
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name_x        7241 non-null   object
#  1   Type          7241 non-null   object
#  2   StartDate     7241 non-null   datetime64[ns]
#  3   EndDate       7241 non-null   datetime64[ns]
#  4   HourlyPay     7241 non-null   object
#  5   merge_id      7241 non-null   object
#  6   ID            7241 non-null   float64
#  7   Name_y        7241 non-null   object
#  8   ContractType  7241 non-null   object
#  9   Date          7241 non-null   datetime64[ns]
#  10  StartTime     7241 non-null   object
#  11  EndTime       7241 non-null   object
# dtypes: datetime64[ns](3), float64(1), object(8)
# memory usage: 735.4+ KB

# %%
(dfall['StartDate'] <= dfall['Date']) & (dfall['Date'] <= dfall['EndDate'])
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7236     True
# 7237     True
# 7238     True
# 7239     True
# 7240     True
# Length: 7241, dtype: bool
